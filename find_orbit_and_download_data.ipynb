# %%
import earthcarekit as eck

# %%
PRODUCT = "ACM_CAP_2B"
ORBIT = ["01164A", "01164B", "01164C", "01164D"]
OUTPUT_PATH = ""

# %%
eck.ecdownload(file_type=PRODUCT , orbit_and_frame=ORBIT)
# Out:
# #======================================================================#
# #                       EarthCARE Download Tool                        #
# #                         earthcarekit 0.15.3                          #
# #======================================================================#
# # Settings
# # - is_download=True
# # - is_overwrite=False
# # - is_unzip=True
# # - is_delete=True
# # - is_create_subdirs=True
# # - is_log=False
# # - is_debug=False
# # - is_export_results=False
# # - idx_selected_input=None
# # - config_filepath=</home/k/k204228/.config/earthcarekit/default_config.toml>
# # - data_dirpath=</home/k/k204228/EarthCARE/data>
#
# +----------------------------------------------------------------------+
# | STEP 1/2 - Search products                       2026-07-03 13:23:14 |
# +----------------------------------------------------------------------+
#
# *[1/4] Search request: ACM_CAP_2B, frame=A, orbits=[1164]
#  [1/4] Files found in collection 'EarthCAREL2Validated_MAAP': 1
# *[2/4] Search request: ACM_CAP_2B, frame=B, orbits=[1164]
#  [2/4] Files found in collection 'EarthCAREL2Validated_MAAP': 1
# *[3/4] Search request: ACM_CAP_2B, frame=C, orbits=[1164]
#  [3/4] Files found in collection 'EarthCAREL2Validated_MAAP': 1
# *[4/4] Search request: ACM_CAP_2B, frame=D, orbits=[1164]
#  [4/4] Files found in collection 'EarthCAREL2Validated_MAAP': 1
#
# List of files found (total number 4):
#  [1]  ECA_EXBA_ACM_CAP_2B_20240811T180657Z_20250905T093700Z_01164A
#  [2]  ECA_EXBA_ACM_CAP_2B_20240811T181834Z_20250905T212703Z_01164B
#  [3]  ECA_EXBA_ACM_CAP_2B_20240811T183021Z_20250905T154509Z_01164C
#  [4]  ECA_EXBA_ACM_CAP_2B_20240811T184126Z_20250905T145558Z_01164D
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
#
# +----------------------------------------------------------------------+
# | STEP 2/2 - Download products                     2026-07-03 13:23:32 |
# +----------------------------------------------------------------------+
#
# *[1/4] Starting: ECA_EXBA_ACM_CAP_2B_20240811T180657Z_20250905T093700Z_01164A
#  [1/4] Skip file download.
#  [1/4] Skip file unzip. (see </home/k/k204228/EarthCARE/data/level2b/ACM_CAP_2B/2024/08/11/BA/ECA_EXBA_ACM_CAP_2B_20240811T180657Z_20250905T093700Z_01164A>)
# *[2/4] Starting: ECA_EXBA_ACM_CAP_2B_20240811T181834Z_20250905T212703Z_01164B
#  [2/4] Download completed (00:00:20 - 2.59 MB/s - 52.55/52.55 MB)
#  [2/4] File extracted and ZIP-file deleted. (see </home/k/k204228/EarthCARE/data/level2b/ACM_CAP_2B/2024/08/11/BA/ECA_EXBA_ACM_CAP_2B_20240811T181834Z_20250905T212703Z_01164B>)
# *[3/4] Starting: ECA_EXBA_ACM_CAP_2B_20240811T183021Z_20250905T154509Z_01164C
#  [3/4] Download completed (00:00:12 - 3.08 MB/s - 38.13/38.13 MB)
#  [3/4] File extracted and ZIP-file deleted. (see </home/k/k204228/EarthCARE/data/level2b/ACM_CAP_2B/2024/08/11/BA/ECA_EXBA_ACM_CAP_2B_20240811T183021Z_20250905T154509Z_01164C>)
# *[4/4] Starting: ECA_EXBA_ACM_CAP_2B_20240811T184126Z_20250905T145558Z_01164D
#  [4/4] Download completed (00:00:12 - 3.75 MB/s - 46.85/46.85 MB)
#  [4/4] File extracted and ZIP-file deleted. (see </home/k/k204228/EarthCARE/data/level2b/ACM_CAP_2B/2024/08/11/BA/ECA_EXBA_ACM_CAP_2B_20240811T184126Z_20250905T145558Z_01164D>)
#
# +----------------------------------------------------------------------+
# | EXECUTION SUMMARY                                2026-07-03 13:24:21 |
# +----------------------------------------------------------------------+
# | Time taken          00:01:12                                         |
# | API search requests 4                                                |
# | Remote files found  4                                                |
# | Files downloaded    3 (137.54 MB at ~2.35 MB/s)                      |
# | Files unzipped      3                                                |
# | Errors occured      0                                                |
# +----------------------------------------------------------------------+

# %%
result = eck.search_product(file_type=PRODUCT)#, orbit_and_frame=ORBIT)
result
# Out:
#   mission_id agency latency baseline   file_type  start_sensing_time  \
# 0        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 16:45:58
# 1        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 16:57:45
# 2        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 17:08:50
# 3        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 17:20:37
# 4        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 18:06:57
# 5        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 18:18:34
# 6        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 18:30:21
# 7        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 18:41:26
# 8        ECA      E       X       BA  ACM_CAP_2B 2024-08-11 18:53:13
#
#   start_processing_time  orbit_number frame_id orbit_and_frame  \
# 0   2025-09-05 19:46:42          1163        B          01163B
# 1   2025-09-05 08:07:39          1163        C          01163C
# 2   2025-09-05 23:13:42          1163        D          01163D
# 3   2025-09-05 13:23:32          1163        E          01163E
# 4   2025-09-05 09:37:00          1164        A          01164A
# 5   2025-09-05 21:27:03          1164        B          01164B
# 6   2025-09-05 15:45:09          1164        C          01164C
# 7   2025-09-05 14:55:58          1164        D          01164D
# 8   2025-09-05 21:39:53          1164        E          01164E
#
#                                             filename  \
# 0  ECA_EXBA_ACM_CAP_2B_20240811T164558Z_20250905T...
# 1  ECA_EXBA_ACM_CAP_2B_20240811T165745Z_20250905T...
# 2  ECA_EXBA_ACM_CAP_2B_20240811T170850Z_20250905T...
# 3  ECA_EXBA_ACM_CAP_2B_20240811T172037Z_20250905T...
# 4  ECA_EXBA_ACM_CAP_2B_20240811T180657Z_20250905T...
# 5  ECA_EXBA_ACM_CAP_2B_20240811T181834Z_20250905T...
# 6  ECA_EXBA_ACM_CAP_2B_20240811T183021Z_20250905T...
# 7  ECA_EXBA_ACM_CAP_2B_20240811T184126Z_20250905T...
# 8  ECA_EXBA_ACM_CAP_2B_20240811T185313Z_20250905T...
#
#                                             filepath  \
# 0  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 1  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 2  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 3  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 4  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 5  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 6  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 7  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
# 8  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...
#
#                                         hdr_filepath  start_latitude  \
# 0  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 1  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 2  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 3  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 4  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 5  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 6  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 7  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
# 8  /home/k/k204228/EarthCARE/data/level2b/ACM_CAP...             NaN
#
#    start_longitude  end_latitude  end_longitude
# 0              NaN           NaN            NaN
# 1              NaN           NaN            NaN
# 2              NaN           NaN            NaN
# 3              NaN           NaN            NaN
# 4              NaN           NaN            NaN
# 5              NaN           NaN            NaN
# 6              NaN           NaN            NaN
# 7              NaN           NaN            NaN
# 8              NaN           NaN            NaN
