# %%
import earthcarekit as eck

# %%
PRODUCT = "ACM_CAP_2B"
ORBIT = ["01164A", "01164B", "01164C", "01164D"]
OUTPUT_PATH = ""

# %%
eck.ecdownload(file_type=PRODUCT , orbit_and_frame=ORBIT)

# %%
result = eck.search_product(file_type=PRODUCT)#, orbit_and_frame=ORBIT)
result

# %%
import earthcarekit as eck

eck.ecdownload("ACM_CAP_2B", start_time="2025-06-17T00:00:00", end_time="2025-06-18T00:00:00")
products = eck.search_product(file_type="ACM_CAP_2B")
# Out:
# #======================================================================#
# #                       EarthCARE Download Tool                        #
# #                         earthcarekit 0.15.3                          #
# #======================================================================#
# # Settings
# # - is_download=True
# # - is_overwrite=False
# # - is_unzip=True
# # - is_delete=True
# # - is_create_subdirs=True
# # - is_log=False
# # - is_debug=False
# # - is_export_results=False
# # - idx_selected_input=None
# # - config_filepath=</home/k/k204228/.config/earthcarekit/default_config.toml>
# # - data_dirpath=</home/k/k204228/EarthCARE/data>
#
# +----------------------------------------------------------------------+
# | STEP 1/2 - Search products                       2026-07-07 14:42:11 |
# +----------------------------------------------------------------------+
#
# *[1/1] Search request: ACM_CAP_2B, time_range=(2025-06-17T00:00:00,2025-06-18T00:00:00)
# ...
